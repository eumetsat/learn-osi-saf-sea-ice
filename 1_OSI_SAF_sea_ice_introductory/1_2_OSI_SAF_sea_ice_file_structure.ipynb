# %% [markdown]
# <img src='https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/tools/frameworks/-/raw/main/img/OSI-SAF_banner.png' align='right' width='100%'/>

# %% [markdown]
# <a href="../Index.ipynb" target="_blank"><< Index</a>
# <br>
# <a href="./1_1b_OSI_SAF_sea_ice_C3S_data_access.ipynb" target="_blank"><< Accessing OSI SAF sea ice products from C3S Data store</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="./1_3a_OSI_SAF_sea_ice_mapping_Ice_Concentration.ipynb" target="_blank">Mapping OSI SAF sea ice concentration >></a>

# %% [markdown]
# <font color="#138D75">**EUMETSAT OSI SAF Training Service**</font> <br>
# **Copyright:** 2026 EUMETSAT <br>
# **License:** MIT

# %% [markdown]
# <html>
#   <div style="width:100%">
#     <div style="float:left"><a href="https://mybinder.org/v2/git/https%3A%2F%2Fgitlab.eumetsat.int%2Feumetlab%2Foceans%2Focean-training%2Fsensors%2Flearn-osi-saf-sea-ice/HEAD?labpath=1_OSI_SAF_sea_ice_introductory%2F1_2_OSI_SAF_sea_ice_file_structure.ipynb"><img src="https://mybinder.org/badge_logo.svg" alt="Open in Binder"></a></div>
#     <div style="float:left"><p>&emsp;</p></div>
#   </div>
# </html>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Learn OSI SAF sea ice parameters : Introductory</h3></div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# The following modules are prerequisites for this notebook, and will retrieve the data required here.
#   - **<a href="./1_1_OSI_SAF_sea_ice_FTP_data_access.ipynb" target="_blank">1_1_OSI_SAF_sea_ice_FTP_data_access.ipynb</a>**
#
# </div>
# <hr>

# %% [markdown]
# # 1.2  Exploring OSI SAF sea ice file structure
# ### Data used
#
# | Dataset | EUMETSAT collection ID | OSI SAF website description | OSI SAF identifier |
# |:-----------------:|:-----------------:|:-----------------:|:-----------------:|
# | Global Sea Ice Concentration (AMSR2) | EO:EUM:DAT:GCOM:OSI-408 | <a href="https://osi-saf.eumetsat.int/products/osi-408-a" target="_blank">Description</a> | OSI-408-a |
# | Global Sea Ice Edge | EO:EUM:DAT:MULT:OSIEDGBN | <a href="https://osi-saf.eumetsat.int/products/osi-402-d" target="_blank">Description</a> | OSI-402-d |
# | Global Sea Ice Type | EO:EUM:DAT:MULT:OSITYGBN | <a href="https://osi-saf.eumetsat.int/products/osi-403-d" target="_blank">Description</a> | OSI-403-d |
# | Global Sea Ice Emissivity | EO:EUM:DAT:DMSP:SISE50 | <a href="https://osi-saf.eumetsat.int/products/osi-404-a" target="_blank">Description</a> | OSI-404-a |
# | Global Low Resolution Sea Ice Drift | EO:EUM:DAT:MULT:GBL-LR-SIDR | <a href="https://osi-saf.eumetsat.int/products/osi-405-c" target="_blank">Description</a> | OSI-405-c |
#
# ### Learning outcomes
#
# At the end of this notebook you will know;
# * What the OSI SAF Sea Ice netcdf files contain
# * What components are inside
# * How to explore the variables that are present
#
# <div class="alert alert-info" role="alert">
#
# ## <a id='TOC-TOP'></a>Contents
#
# </div>
#
#  1. [Querying OSI SAF Sea Ice file structure](#section1)
#
# <hr>

# %% [markdown]
# We begin by importing all of the libraries that we need to run this notebook. If you have built your python using the environment file provided in this repository, then you should have everything you need. For more information on building environment, please see the repository **<a href="../README.md" target="_blank">README</a>**.

# %%
# library imports 
import os                                     # a library that allows us access to basic operating system commands
import xarray as xr                           # a library that supports the use of multi-dimensional arrays in Python

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>1. Querying OSI SAF Sea Ice Concentration file structure
# [Back to top](#TOC-TOP)
#
# </div>

# %% [markdown]
# ### Ice concentration (Near Real Time products):

# %% [markdown]
# Let's start by defining the dataset we want to explore

# %%
directory = os.path.join(os.getcwd(), 'products', 'SI_concentration_AMSR2', 'nh')

# %% [markdown]
# Explore the directory and open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(os.path.join(directory, filename))

# %% [markdown]
# We can now browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset> Size: 27MB
# Dimensions:                   (time: 1, nv: 2, xc: 760, yc: 1120)
# Coordinates:
#   * time                      (time) datetime64[ns] 8B 2025-03-16T12:00:00
#   * xc                        (xc) float64 6kB -3.845e+03 ... 3.745e+03
#   * yc                        (yc) float64 9kB 5.845e+03 ... -5.345e+03
#     lat                       (yc, xc) float32 3MB ...
#     lon                       (yc, xc) float32 3MB ...
# Dimensions without coordinates: nv
# Data variables:
#     Polar_Stereographic_Grid  int32 4B ...
#     time_bnds                 (time, nv) datetime64[ns] 16B ...
#     ice_conc                  (time, yc, xc) float32 3MB ...
#     raw_ice_conc_values       (time, yc, xc) float32 3MB ...
#     status_flag               (time, yc, xc) float32 3MB ...
#     total_uncertainty         (time, yc, xc) float32 3MB ...
#     smearing_uncertainty      (time, yc, xc) float32 3MB ...
#     algorithm_uncertainty     (time, yc, xc) float32 3MB ...
# Attributes: (12/30)
#     title:                   Level-3 Sea Ice Concentration Analysis (AMSR2) f...
#     product_id:              OSI-408-a
#     instrument_type:         AMSR2
#     platform_name:           GCOM-W
#     easternmost_longitude:   180.0
#     westernmost_longitude:   -180.0
#     ...                      ...
#     references:              Product User Manual and Algorithm Theoretical Ba...
#     history:                 Created 2025-03-17 02:00:59
#     product_version:         4.1
#     software_version:        2.0.4
#     netcdf_version:          1.5.4
#     Conventions:             CF-1.6

# %% [markdown]
# Let's have a look at some variable in detail.
# You can explore now explore individual variables. As an example :
# * ice_conc

# %%
nc.variables['ice_conc']
# Out:
# <xarray.Variable (time: 1, yc: 1120, xc: 760)> Size: 3MB
# [851200 values with dtype=float32]
# Attributes:
#     long_name:      sea ice concentration derived applying the status_flag to...
#     standard_name:  sea_ice_area_fraction
#     comment:        this field is the primary sea ice concentration estimate ...
#     units:          %
#     grid_mapping:   Polar_Stereographic_Grid

# %% [markdown]
# Let's have a particular look at the projection in which this product is distribute. This will be particularly important to plot it.

# %%
nc.variables['Polar_Stereographic_Grid']
# Out:
# <xarray.Variable ()> Size: 4B
# [1 values with dtype=int32]
# Attributes:
#     grid_mapping_name:                      polar_stereographic
#     false_easting:                          0.0
#     false_northing:                         0.0
#     area_extent:                            '(-3850000.0, -5350000.0, 3750000...
#     semi_major_axis:                        6378273.0
#     semi_minor_axis:                        6356889.44891
#     straight_vertical_longitude_from_pole:  -45.0
#     latitude_of_projection_origin:          90.0
#     standard_parallel:                      70.0
#     proj4_string:                           +proj=stere +a=6378273 +b=6356889...

# %% [markdown]
# If you look in the detail, the 'proj4_string' provides us with important information to define our input data. Here we do have:
# Stereographic projection with:
# - central_latitude=90.0 (geographic north pole)
# - central_longitude=-45.0 (the southern tip of Greenland will be in the center line of the plot)
# - true scale latitude=70.0
#
# **Polar Stereographic** is the projection we are using for all our **Near Real Time products**. It is an historical choice, to fit with the other Sea Ice product distributed. Let's then have a look at the situation for the climate products.

# %%
nc.close()

# %% [markdown]
# ### Ice concentration (Climate products):

# %% [markdown]
# Let's explore now the SMMR/ SSM/I /SSMIS Climate Data Record product projection

# %%
directory = os.path.join(os.getcwd(), 'products', 'SI_concentration_SSM_CDR3_1', 'nh')

# %% [markdown]
# We open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(os.path.join(directory, filename))

# %% [markdown]
# And now, we can browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:                         (time: 1, nv: 2, xc: 432, yc: 432)
# Coordinates:
#   * time                            (time) datetime64[ns] 8B 2013-06-12T12:00:00
#   * xc                              (xc) float64 3kB -5.388e+03 ... 5.388e+03
#   * yc                              (yc) float64 3kB 5.388e+03 ... -5.388e+03
#     lat                             (yc, xc) float32 746kB ...
#     lon                             (yc, xc) float32 746kB ...
# Dimensions without coordinates: nv
# Data variables:
#     Lambert_Azimuthal_Grid          int32 4B ...
#     time_bnds                       (time, nv) datetime64[ns] 16B ...
#     ice_conc                        (time, yc, xc) float64 1MB ...
#     raw_ice_conc_values             (time, yc, xc) float64 1MB ...
#     total_standard_uncertainty      (time, yc, xc) float64 1MB ...
#     smearing_standard_uncertainty   (time, yc, xc) float64 1MB ...
#     algorithm_standard_uncertainty  (time, yc, xc) float64 1MB ...
#     status_flag                     (time, yc, xc) float32 746kB ...
# Attributes: (12/43)
#     title:                     Sea Ice Concentration Climate Data Record Vers...
#     summary:                   This climate data record of sea ice concentrat...
#     topiccategory:             Oceans ClimatologyMeteorologyAtmosphere
#     geospatial_lat_min:        16.62393
#     geospatial_lat_max:        90.0
#     geospatial_lon_min:        -180.0
#     ...                        ...
#     product_version:           3.1
#     doi:                       10.15770/EUM_SAF_OSI_0023
#     product_id:                osi-450-a1
#     references:                Product User Manual (2025),Algorithm Theoretic...
#     history:                   2022-06-08T12:56:09Z creation\n2025-02-14T09:4...
#     license:                   http://creativecommons.org/licenses/by/4.0/

# %% [markdown]
# Here we can see that the projection in wich is distribute this product is the **Lambert Azimuthal Equal-Area**.
# Let's explore it into details.

# %%
nc.variables['Lambert_Azimuthal_Grid']
# Out:
# <xarray.Variable ()> Size: 4B
# [1 values with dtype=int32]
# Attributes:
#     grid_mapping_name:               lambert_azimuthal_equal_area
#     longitude_of_projection_origin:  0.0
#     latitude_of_projection_origin:   90.0
#     false_easting:                   0.0
#     false_northing:                  0.0
#     semi_major_axis:                 6378137.0
#     inverse_flattening:              298.257223563
#     proj4_string:                    +proj=laea +lon_0=0 +datum=WGS84 +ellps=...

# %% [markdown]
# If you look in the detail, the 'proj4_string' provides us with important information to define our input data. Here we do have:
# Stereographic projection with:
# - central_latitude=90.0 (geographic north pole)
# - central_longitude=0.0 (greenwich will be the center of our sheet)
#
# **Lambert Azimuthal Equal-Area** is the projection we are using for all **OSI SAF Climate products**. This choice was made because it is better fitted for Sea Ice studies than the Stereographic one.

# %%
nc.close()

# %% [markdown]
# Define the dataset we want to explore

# %%
directory = os.path.join(os.getcwd(), 'products', 'SI_type', 'nh')

# %% [markdown]
# ### Ice Type :

# %% [markdown]
# Explore the directory and open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(os.path.join(directory, filename))

# %% [markdown]
# We can now browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:                   (time: 1, nv: 2, xc: 760, yc: 1120)
# Coordinates:
#   * time                      (time) datetime64[ns] 8B 2024-12-25T12:00:00
#   * xc                        (xc) float64 6kB -3.84e+03 -3.83e+03 ... 3.74e+03
#   * yc                        (yc) float64 9kB 5.84e+03 5.83e+03 ... -5.34e+03
#     lat                       (yc, xc) float32 3MB ...
#     lon                       (yc, xc) float32 3MB ...
# Dimensions without coordinates: nv
# Data variables:
#     Polar_Stereographic_Grid  int32 4B ...
#     time_bnds                 (time, nv) datetime64[ns] 16B ...
#     ice_type                  (time, yc, xc) float32 3MB ...
#     status_flag               (time, yc, xc) float32 3MB ...
#     uncertainty               (time, yc, xc) float32 3MB ...
#     param_used                (time, yc, xc) float32 3MB ...
#     orbit_num_ascat           (time, yc, xc) float32 3MB ...
#     orbit_num_amsr            (time, yc, xc) float32 3MB ...
#     orbit_num_ssmis           (time, yc, xc) float32 3MB ...
# Attributes: (12/33)
#     title:                  Daily Sea Ice Type Analysis from OSI SAF EUMETSAT
#     id:                     OSI-403-d
#     product_id:             OSI-403-d
#     product_name:           osi_saf_ice_type
#     product_status:         operational
#     processing_level:       Level-3 (l3)
#     ...                     ...
#     history:                2024-12-26 creation
#     product_version:        5.0
#     software_version:       5.3
#     netcdf_version:         4.7.4
#     Conventions:            CF-1.7
#     date_created:           2024-12-26 04:25:36.147492

# %% [markdown]
# Have you had a detailed look at the diferent variables and attributes from the xarray output ?
# You can explore now explore individual variables. As an example :
# * ice_type

# %%
nc.variables['ice_type']
# Out:
# <xarray.Variable (time: 1, yc: 1120, xc: 760)> Size: 3MB
# [851200 values with dtype=float32]
# Attributes:
#     long_name:          sea ice type
#     standard_name:      sea_ice_classification
#     valid_min:          1
#     valid_max:          4
#     grid_mapping:       Polar_Stereographic_Grid
#     flag_values:        [1 2 3 4]
#     flag_meanings:      open_water first_year_ice multi_year_ice ambiguous
#     flag_descriptions:  1 -> no ice or very open ice\n 2 -> relatively young ...

# %% [markdown]
# The ice_type can be of 4 values :
# * 1 -> no ice or very open ice
# * 2 -> relatively young ice
# * 3 -> ice that survived a summer melt
# * 4 -> ambiguous ice type

# %%
nc.close()

# %% [markdown]
# ### Ice Edge :

# %% [markdown]
# Define the dataset we want to explore

# %%
directory = os.path.join(os.getcwd(), 'products', 'SI_edge', 'nh')

# %% [markdown]
# Explore the directory and open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(os.path.join(directory, filename))

print(filename)
# Out:
# ice_edge_nh_polstere-100_multi_202504171200.nc

# %% [markdown]
# We can now browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:                   (time: 1, nv: 2, xc: 760, yc: 1120)
# Coordinates:
#   * time                      (time) datetime64[ns] 8B 2025-04-17T12:00:00
#   * xc                        (xc) float64 6kB -3.84e+03 -3.83e+03 ... 3.74e+03
#   * yc                        (yc) float64 9kB 5.84e+03 5.83e+03 ... -5.34e+03
#     lat                       (yc, xc) float32 3MB ...
#     lon                       (yc, xc) float32 3MB ...
# Dimensions without coordinates: nv
# Data variables:
#     Polar_Stereographic_Grid  int32 4B ...
#     time_bnds                 (time, nv) datetime64[ns] 16B ...
#     ice_edge                  (time, yc, xc) float32 3MB ...
#     status_flag               (time, yc, xc) float32 3MB ...
#     uncertainty               (time, yc, xc) float32 3MB ...
#     param_used                (time, yc, xc) float32 3MB ...
#     orbit_num_ascat           (time, yc, xc) float32 3MB ...
#     orbit_num_amsr            (time, yc, xc) float32 3MB ...
#     orbit_num_ssmis           (time, yc, xc) float32 3MB ...
# Attributes: (12/33)
#     title:                  Daily Sea Ice Edge Analysis from OSI SAF EUMETSAT
#     id:                     OSI-402-d
#     product_id:             OSI-402-d
#     product_name:           osi_saf_ice_edge
#     product_status:         operational
#     processing_level:       Level-3 (l3)
#     ...                     ...
#     history:                2025-04-18 creation
#     product_version:        5.0
#     software_version:       5.3
#     netcdf_version:         4.7.4
#     Conventions:            CF-1.7
#     date_created:           2025-04-18 04:22:55.813375

# %% [markdown]
# Have you had a detailed look at the diferent variables and attributes from the xarray output ?
# You can explore now explore individual variables. As an example :
# * ice_edge

# %%
nc.variables['ice_edge']
# Out:
# <xarray.Variable (time: 1, yc: 1120, xc: 760)> Size: 3MB
# [851200 values with dtype=float32]
# Attributes:
#     long_name:          sea ice edge
#     standard_name:      sea_ice_classification
#     valid_min:          1
#     valid_max:          3
#     grid_mapping:       Polar_Stereographic_Grid
#     flag_values:        [1 2 3]
#     flag_meanings:      open_water open_ice close_ice
#     flag_descriptions:  1 -> no ice or very open ice\n 2 -> open ice cover (4...

# %% [markdown]
# The ice_edge variable is represented with 3 values :
# * 1 -> no ice or very open ice
# * 2 -> open ice cover (4 to 7 tens)
# * 3 -> close, very close and fast ice

# %%
nc.close()

# %% [markdown]
# ### Ice Emissivity :

# %% [markdown]
# Define the dataset we want to explore

# %%
directory = os.path.join(os.getcwd(), 'products', 'SI_emissivity', 'nh')

# %% [markdown]
# Explore the directory and open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(os.path.join(directory, filename))

# %% [markdown]
# We can now browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset> Size: 54MB
# Dimensions:                   (xc: 760, yc: 1120)
# Coordinates:
#   * xc                        (xc) float64 6kB -3.845e+03 ... 3.745e+03
#   * yc                        (yc) float64 9kB 5.845e+03 ... -5.345e+03
#     lat                       (yc, xc) float32 3MB ...
#     lon                       (yc, xc) float32 3MB ...
# Data variables:
#     Polar_Stereographic_Grid  int32 4B ...
#     eh                        (yc, xc) float32 3MB ...
#     ev                        (yc, xc) float32 3MB ...
#     e                         (yc, xc) float32 3MB ...
#     R                         (yc, xc) float32 3MB ...
#     S                         (yc, xc) float32 3MB ...
#     teff                      (yc, xc) float32 3MB ...
#     eh_alt                    (yc, xc) float32 3MB ...
#     u                         (yc, xc) float32 3MB ...
#     status_flag_input         (yc, xc) float64 7MB ...
#     status_flag_product       (yc, xc) float64 7MB ...
#     status_flag_alternative   (yc, xc) float64 7MB ...
# Attributes: (12/49)
#     title:                     Global Sea Ice Emissivity
#     summary:                   Gridded sea ice surface emissivity representat...
#     algorithm:                 OSI SAF emissivity
#     product_name:              osi_saf_ice_emis
#     product_status:            demonstration
#     Conventions:               CF-1.7,ACDD-1.3
#     ...                        ...
#     spatial_resolution:        10 km grid spacing
#     time_coverage_start:       2025-09-22T00:00:00Z
#     time_coverage_end:         2025-09-23T00:00:00Z
#     time_coverage_duration:    P1D
#     time_coverage_resolution:  P1D
#     iso_topic_category:        Oceans ClimatologyMeteorologyAtmosphere

# %% [markdown]
# Sea Ice Emisivity data file provide 4 types of variables :
# * The nadir 50GHz emissivity : e
# * The 50GHz vertically polarised emissivity at 50 deg incidence angle : ev
# * R coefficient describing the polarisation
# * S coefficient describing the nadir emissivity

# %%
nc.close()

# %% [markdown]
# ### Ice Drift :

# %% [markdown]
# Define the dataset we want to explore

# %%
directory = os.path.join(os.getcwd(), 'products', 'SI_drift')

# %% [markdown]
# Explore the directory and open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(os.path.join(directory, filename))

# %% [markdown]
# We can now browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset> Size: 54MB
# Dimensions:                   (xc: 760, yc: 1120)
# Coordinates:
#   * xc                        (xc) float64 6kB -3.845e+03 ... 3.745e+03
#   * yc                        (yc) float64 9kB 5.845e+03 ... -5.345e+03
#     lat                       (yc, xc) float32 3MB ...
#     lon                       (yc, xc) float32 3MB ...
# Data variables:
#     Polar_Stereographic_Grid  int32 4B ...
#     eh                        (yc, xc) float32 3MB ...
#     ev                        (yc, xc) float32 3MB ...
#     e                         (yc, xc) float32 3MB ...
#     R                         (yc, xc) float32 3MB ...
#     S                         (yc, xc) float32 3MB ...
#     teff                      (yc, xc) float32 3MB ...
#     eh_alt                    (yc, xc) float32 3MB ...
#     u                         (yc, xc) float32 3MB ...
#     status_flag_input         (yc, xc) float64 7MB ...
#     status_flag_product       (yc, xc) float64 7MB ...
#     status_flag_alternative   (yc, xc) float64 7MB ...
# Attributes: (12/49)
#     title:                     Global Sea Ice Emissivity
#     summary:                   Gridded sea ice surface emissivity representat...
#     algorithm:                 OSI SAF emissivity
#     product_name:              osi_saf_ice_emis
#     product_status:            demonstration
#     Conventions:               CF-1.7,ACDD-1.3
#     ...                        ...
#     spatial_resolution:        10 km grid spacing
#     time_coverage_start:       2025-09-22T00:00:00Z
#     time_coverage_end:         2025-09-23T00:00:00Z
#     time_coverage_duration:    P1D
#     time_coverage_resolution:  P1D
#     iso_topic_category:        Oceans ClimatologyMeteorologyAtmosphere

# %%
nc.close()

# %% [markdown]
# <hr>
# <a href="../Index.ipynb" target="_blank"><< Index</a>
# <br>
# <a href="./1_1b_OSI_SAF_sea_ice_C3S_data_access.ipynb" target="_blank"><< Accessing OSI SAF sea ice products from C3S Data store</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="./1_3a_OSI_SAF_sea_ice_mapping_Ice_Concentration.ipynb" target="_blank">Mapping OSI SAF sea ice concentration >></a>
# <hr>
# <a href="https://gitlab.eumetsat.int/eumetlab/ocean">View on GitLab</a> | <a href="https://training.eumetsat.int/">EUMETSAT Training</a> | <a href=mailto:ops@eumetsat.int>Contact helpdesk for support </a> | <a href=mailto:training@eumetsat.int>Contact our training team to collaborate on and reuse this material</a></span></p>
